# %%
from selenium import webdriver
import time

# %%
wb = webdriver.Chrome()
wb.get('https://www.premierleague.com/results')

# %%
btn = wb.find_elements_by_class_name('btn-primary')[1]
btn.click()

# %%
SCROLL_PAUSE_TIME = 1

# Get scroll height
last_height = wb.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    wb.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = wb.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
match_days = wb.find_elements_by_class_name('fixtures__matches-list')

match_days_dic = {}

for match_day in match_days:
    date = match_day.get_attribute('data-competition-matches-list')
    match_day_list = match_day.text.split('\n')
    match_days_dic[date] = []
    
    for i in range(0, len(match_day_list), 3):
        match_days_dic[date].append(' '.join(match_day_list[i:i+3]))

# %%
match_days_dic
# Out:
# {'Thursday 4 February 2021': ['Spurs 0-1 Chelsea'],
#  'Wednesday 3 February 2021': ['Burnley 0-2 Man City',
#   'Fulham 0-2 Leicester',
#   'Leeds 1-2 Everton',
#   'Aston Villa 1-3 West Ham',
#   'Liverpool 0-1 Brighton'],
#  'Tuesday 2 February 2021': ['Sheffield Utd 2-1 West Brom',
#   'Wolves 2-1 Arsenal',
#   'Man Utd 9-0 Southampton',
#   'Newcastle 1-2 Crystal Palace'],
#  'Sunday 31 January 2021': ['Chelsea 2-0 Burnley',
#   'Leicester 1-3 Leeds',
#   'West Ham 1-3 Liverpool',
#   'Brighton 1-0 Spurs'],
#  'Saturday 30 January 2021': ['Everton 0-2 Newcastle',
#   'Crystal Palace 1-0 Wolves',
#   'Man City 1-0 Sheffield Utd',
#   'West Brom 2-2 Fulham',
#   'Arsenal 0-0 Man Utd',
#   'Southampton 0-1 Aston Villa'],
#  'Thursday 28 January 2021': ['Spurs 1-3 Liverpool'],
#  'Wednesday 27 January 2021': ['Burnley 3-2 Aston Villa',
#   'Chelsea 0-0 Wolves',
#   'Brighton 0-0 Fulham',
#   'Everton 1-1 Leicester',
#   'Man Utd 1-2 Sheffield Utd'],
#  'Tuesday 26 January 2021': ['Crystal Palace 2-3 West Ham',
#   'Newcastle 1-2 Leeds',
#   'Southampton 1-3 Arsenal',
#   'West Brom 0-5 Man City'],
#  'Saturday 23 January 2021': ['Aston Villa 2-0 Newcastle'],
#  'Thursday 21 January 2021': ['Liverpool 0-1 Burnley'],
#  'Wednesday 20 January 2021': ['Man City 2-0 Aston Villa',
#   'Fulham 1-2 Man Utd'],
#  'Tuesday 19 January 2021': ['West Ham 2-1 West Brom',
#   'Leicester 2-0 Chelsea'],
#  'Monday 18 January 2021': ['Arsenal 3-0 Newcastle'],
#  'Sunday 17 January 2021': ['Sheffield Utd 1-3 Spurs',
#   'Liverpool 0-0 Man Utd',
#   'Man City 4-0 Crystal Palace'],
#  'Saturday 16 January 2021': ['Wolves 2-3 West Brom',
#   'Leeds 0-1 Brighton',
#   'West Ham 1-0 Burnley',
#   'Fulham 0-1 Chelsea',
#   'Leicester 2-0 Southampton'],
#  'Thursday 14 January 2021': ['Arsenal 0-0 Crystal Palace'],
#  'Wednesday 13 January 2021': ['Man City 1-0 Brighton', 'Spurs 1-1 Fulham'],
#  'Tuesday 12 January 2021': ['Sheffield Utd 1-0 Newcastle',
#   'Burnley 0-1 Man Utd',
#   'Wolves 1-2 Everton'],
#  'Monday 4 January 2021': ['Southampton 1-0 Liverpool'],
#  'Sunday 3 January 2021': ['Newcastle 1-2 Leicester', 'Chelsea 1-3 Man City'],
#  'Saturday 2 January 2021': ['Spurs 3-0 Leeds',
#   'Crystal Palace 2-0 Sheffield Utd',
#   'Brighton 3-3 Wolves',
#   'West Brom 0-4 Arsenal'],
#  'Friday 1 January 2021': ['Everton 0-1 West Ham', 'Man Utd 2-1 Aston Villa'],
#  'Wednesday 30 December 2020': ['Newcastle 0-0 Liverpool'],
#  'Tuesday 29 December 2020': ['Brighton 0-1 Arsenal',
#   'Burnley 1-0 Sheffield Utd',
#   'Southampton 0-0 West Ham',
#   'West Brom 0-5 Leeds',
#   'Man Utd 1-0 Wolves'],
#  'Monday 28 December 2020': ['Crystal Palace 1-1 Leicester',
#   'Chelsea 1-1 Aston Villa'],
#  'Sunday 27 December 2020': ['Leeds 1-0 Burnley',
#   'West Ham 2-2 Brighton',
#   'Liverpool 1-1 West Brom',
#   'Wolves 1-1 Spurs'],
#  'Saturday 26 December 2020': ['Leicester 2-2 Man Utd',
#   'Aston Villa 3-0 Crystal Palace',
#   'Fulham 0-0 Southampton',
#   'Arsenal 3-1 Chelsea',
#   'Man City 2-0 Newcastle',
#   'Sheffield Utd 0-1 Everton'],
#  'Monday 21 December 2020': ['Burnley 2-1 Wolves', 'Chelsea 3-0 West Ham'],
#  'Sunday 20 December 2020': ['Brighton 1-1 Sheffield Utd',
#   'Spurs 0-2 Leicester',
#   'Man Utd 6-2 Leeds',
#   'West Brom 0-3 Aston Villa'],
#  'Saturday 19 December 2020': ['Crystal Palace 0-7 Liverpool',
#   'Southampton 0-1 Man City',
#   'Everton 2-1 Arsenal',
#   'Newcastle 1-1 Fulham'],
#  'Thursday 17 December 2020': ['Aston Villa 0-0 Burnley',
#   'Sheffield Utd 2-3 Man Utd'],
#  'Wednesday 16 December 2020': ['Arsenal 1-1 Southampton',
#   'Leeds 5-2 Newcastle',
#   'Leicester 0-2 Everton',
#   'Fulham 0-0 Brighton',
#   'Liverpool 2-1 Spurs',
#   'West Ham 1-1 Crystal Palace'],
#  'Tuesday 15 December 2020': ['Wolves 2-1 Chelsea', 'Man City 1-1 West Brom'],
#  'Sunday 13 December 2020': ['Southampton 3-0 Sheffield Utd',
#   'Crystal Palace 1-1 Spurs',
#   'Fulham 1-1 Liverpool',
#   'Arsenal 0-1 Burnley',
#   'Leicester 3-0 Brighton'],
#  'Saturday 12 December 2020': ['Wolves 0-1 Aston Villa',
#   'Newcastle 2-1 West Brom',
#   'Man Utd 0-0 Man City',
#   'Everton 1-0 Chelsea'],
#  'Friday 11 December 2020': ['Leeds 1-2 West Ham'],
#  'Monday 7 December 2020': ['Brighton 1-2 Southampton'],
#  'Sunday 6 December 2020': ['West Brom 1-5 Crystal Palace',
#   'Sheffield Utd 1-2 Leicester',
#   'Spurs 2-0 Arsenal',
#   'Liverpool 4-0 Wolves'],
#  'Saturday 5 December 2020': ['Burnley 1-1 Everton',
#   'Man City 2-0 Fulham',
#   'West Ham 1-3 Man Utd',
#   'Chelsea 3-1 Leeds'],
#  'Monday 30 November 2020': ['Leicester 1-2 Fulham',
#   'West Ham 2-1 Aston Villa'],
#  'Sunday 29 November 2020': ['Arsenal 1-2 Wolves',
#   'Southampton 2-3 Man Utd',
#   'Chelsea 0-0 Spurs'],
#  'Saturday 28 November 2020': ['Brighton 1-1 Liverpool',
#   'Man City 5-0 Burnley',
#   'Everton 0-1 Leeds',
#   'West Brom 1-0 Sheffield Utd'],
#  'Friday 27 November 2020': ['Crystal Palace 0-2 Newcastle'],
#  'Monday 23 November 2020': ['Burnley 1-0 Crystal Palace',
#   'Wolves 1-1 Southampton'],
#  'Sunday 22 November 2020': ['Fulham 2-3 Everton',
#   'Sheffield Utd 0-1 West Ham',
#   'Leeds 0-0 Arsenal',
#   'Liverpool 3-0 Leicester'],
#  'Saturday 21 November 2020': ['Newcastle 0-2 Chelsea',
#   'Aston Villa 1-2 Brighton',
#   'Spurs 2-0 Man City',
#   'Man Utd 1-0 West Brom'],
#  'Sunday 8 November 2020': ['West Brom 0-1 Spurs',
#   'Leicester 1-0 Wolves',
#   'Man City 1-1 Liverpool',
#   'Arsenal 0-3 Aston Villa'],
#  'Saturday 7 November 2020': ['Everton 1-3 Man Utd',
#   'Crystal Palace 4-1 Leeds',
#   'Chelsea 4-1 Sheffield Utd',
#   'West Ham 1-0 Fulham'],
#  'Friday 6 November 2020': ['Brighton 0-0 Burnley',
#   'Southampton 2-0 Newcastle'],
#  'Monday 2 November 2020': ['Fulham 2-0 West Brom', 'Leeds 1-4 Leicester'],
#  'Sunday 1 November 2020': ['Aston Villa 3-4 Southampton',
#   'Newcastle 2-1 Everton',
#   'Man Utd 0-1 Arsenal',
#   'Spurs 2-1 Brighton'],
#  'Saturday 31 October 2020': ['Sheffield Utd 0-1 Man City',
#   'Burnley 0-3 Chelsea',
#   'Liverpool 2-1 West Ham'],
#  'Friday 30 October 2020': ['Wolves 2-0 Crystal Palace'],
#  'Monday 26 October 2020': ['Brighton 1-1 West Brom', 'Burnley 0-1 Spurs'],
#  'Sunday 25 October 2020': ['Arsenal 0-1 Leicester',
#   'Southampton 2-0 Everton',
#   'Wolves 1-1 Newcastle'],
#  'Saturday 24 October 2020': ['West Ham 1-1 Man City',
#   'Fulham 1-2 Crystal Palace',
#   'Man Utd 0-0 Chelsea',
#   'Liverpool 2-1 Sheffield Utd'],
#  'Friday 23 October 2020': ['Aston Villa 0-3 Leeds'],
#  'Monday 19 October 2020': ['West Brom 0-0 Burnley', 'Leeds 0-1 Wolves'],
#  'Sunday 18 October 2020': ['Sheffield Utd 1-1 Fulham',
#   'Crystal Palace 1-1 Brighton',
#   'Spurs 3-3 West Ham',
#   'Leicester 0-1 Aston Villa'],
#  'Saturday 17 October 2020': ['Everton 2-2 Liverpool',
#   'Chelsea 3-3 Southampton',
#   'Man City 1-0 Arsenal',
#   'Newcastle 1-4 Man Utd'],
#  'Sunday 4 October 2020': ['Leicester 0-3 West Ham',
#   'Southampton 2-0 West Brom',
#   'Arsenal 2-1 Sheffield Utd',
#   'Wolves 1-0 Fulham',
#   'Man Utd 1-6 Spurs',
#   'Aston Villa 7-2 Liverpool'],
#  'Saturday 3 October 2020': ['Chelsea 4-0 Crystal Palace',
#   'Everton 4-2 Brighton',
#   'Leeds 1-1 Man City',
#   'Newcastle 3-1 Burnley'],
#  'Monday 28 September 2020': ['Fulham 0-3 Aston Villa',
#   'Liverpool 3-1 Arsenal'],
#  'Sunday 27 September 2020': ['Sheffield Utd 0-1 Leeds',
#   'Spurs 1-1 Newcastle',
#   'Man City 2-5 Leicester',
#   'West Ham 4-0 Wolves'],
#  'Saturday 26 September 2020': ['Brighton 2-3 Man Utd',
#   'Crystal Palace 1-2 Everton',
#   'West Brom 3-3 Chelsea',
#   'Burnley 0-1 Southampton'],
#  'Monday 21 September 2020': ['Aston Villa 1-0 Sheffield Utd',
#   'Wolves 1-3 Man City'],
#  'Sunday 20 September 2020': ['Leicester 4-2 Burnley',
#   'Southampton 2-5 Spurs',
#   'Newcastle 0-3 Brighton',
#   'Chelsea 0-2 Liverpool'],
#  'Saturday 19 September 2020': ['Everton 5-2 West Brom',
#   'Leeds 4-3 Fulham',
#   'Man Utd 1-3 Crystal Palace',
#   'Arsenal 2-1 West Ham'],
#  'Monday 14 September 2020': ['Sheffield Utd 0-2 Wolves',
#   'Brighton 1-3 Chelsea'],
#  'Sunday 13 September 2020': ['West Brom 0-3 Leicester', 'Spurs 0-1 Everton'],
#  'Saturday 12 September 2020': ['Fulham 0-3 Arsenal',
#   'Crystal Palace 1-0 Southampton',
#   'Liverpool 4-3 Leeds',
#   'West Ham 0-2 Newcastle']}
